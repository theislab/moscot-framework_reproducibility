# %%
library(anndata)
library(Signac)
library(Seurat)
library(anndata)
library(ggplot2)
library(tidyverse)
library(Signac)
library(Seurat)
#library(EnsDb.Mmusculus.v102)
library(BSgenome.Mmusculus.UCSC.mm10)
#library(pastecs)
library(stringr)
# Out:
# Attaching SeuratObject
#
# Attaching sp
#
# ── Attaching packages ────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.3     ✔ forcats 0.5.1
# ✔ purrr   0.3.4
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter()   masks stats::filter()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ readr::read_csv() masks anndata::read_csv()
# ✖ purrr::reduce()   masks Signac::reduce()
# Lade nötiges Paket: BSgenome
#
# Lade nötiges Paket: BiocGenerics
#
#
# Attache Paket: ‘BiocGenerics’
#
#
# Die folgenden Objekte sind maskiert von ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# Die folgenden Objekte sind maskiert von ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# Die folgenden Objekte sind maskiert von ‘package:base’:
#
# ...

# %%
cols <- c('#f7b6d2', '#d62728', '#ffbb78',  '#98df8a',
    '#1f77b4', '#ff7f0e',  '#279e68',  '#aa40fc', '#8c564b',
        '#e377c2',  '#b5bd61',  '#aec7e8',  '#aec7e8',  '#ffbb78', '#98df8a',
        '#17becf', '#aec7e8',
         '#ff9896', '#f0b98d', '#c5b0d5')

# %%
seurat <- readRDS("/Users/dominik.klein/data/seurat_filtered.rds")

# %%
Idents(seurat) <- seurat@meta.data[["Fev_delta_refinement"]]

# %% [markdown]
# # Delta

# %%
delta_regions = 
c("16-72640851-72641699",
 "3-39062154-39063049",
 "19-4124163-4124803",
 "17-81018425-81019354",
 "10-5865738-5866637")

# %%
seurat
# Out:
# An object of class Seurat
# 475329 features across 16918 samples within 3 assays
# Active assay: ATAC_merged (228259 features, 228259 variable features)
#  2 other assays present: RNA, ATAC
#  1 dimensional reduction calculated: lsi

# %%
p <- CoveragePlot(
  object = seurat,
  region = delta_regions[[1]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, delta_regions[[1]])$gene_name
)

# %%
ids <- c('Alpha', 'Beta', 'Delta', 'Ductal', 'Eps. progenitors', 'Epsilon',
       'Fev+', 'Fev+ Alpha', 'Fev+ Beta', 'Fev+ Delta,0', 'Fev+ Delta,1',
       'Fev+ Delta,2', 'Imm. Acinar', 'Mat. Acinar', 'Ngn3 high',
       'Ngn3 high cycling', 'Ngn3 low', 'Prlf. Ductal')

# %%
p <- CoveragePlot(
  object = seurat,
  region = delta_regions[[1]],
  annotation = TRUE,
  idents=ids,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, delta_regions[[1]])$gene_name
)

# %%
seurat@meta.data$refinement <- factor(seurat@meta.data$Fev_delta_refinement, levels = ids)

# %%
p <- CoveragePlot(
  object = seurat,
  region = delta_regions[[1]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, delta_regions[[1]])$gene_name,
)

# %%
p & scale_fill_manual(values=cols)
# Out:
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# Scale for fill is already present.
# Adding another scale for fill, which will replace the existing scale.
# ERROR while rich displaying an object: Error in `palette()`:
# ! Insufficient values in manual scale. 18 needed but only 1 provided.
#
# Traceback:
# 1. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 2. tryCatchList(expr, classes, parentenv, handlers)
# 3. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 4. doTryCatch(return(expr), name, parentenv, handler)
# 5. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
# ...

# %%
CoveragePlot(
  object = seurat,
  region = delta_regions[[2]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, delta_regions[[2]])$gene_name
)
# Out:
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = delta_regions[[3]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 500,
  extend.downstream = 500,
  features=ClosestFeature(seurat, delta_regions[[3]])$gene_name
)
# Out:
# Warning message:
# “Removed 24 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = delta_regions[[4]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, delta_regions[[4]])$gene_name
)
# Out:
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = delta_regions[[5]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, delta_regions[[5]])$gene_name
)
# Out:
# Warning message:
# “Removed 24 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %% [markdown]
# # Epsilon

# %%
eps_regions = 
c("10-64082077-64082994",
 "2-155892590-155893351",
 "4-57291831-57292786",
 "3-79085915-79086814",
 "9-11562792-11563740")

# %%
CoveragePlot(
  object = seurat,
  region = eps_regions[[1]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, eps_regions[[1]])$gene_name
)
# Out:
# Warning message:
# “Removed 68 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = eps_regions[[2]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, eps_regions[[2]])$gene_name
)
# Out:
# Warning message:
# “Removed 134 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = eps_regions[[3]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, eps_regions[[3]])$gene_name
)
# Out:
# Warning message:
# “Removed 50 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = eps_regions[[4]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, eps_regions[[4]])$gene_name
)
# Out:
# Warning message:
# “Removed 81 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
features=ClosestFeature(seurat, "9-11562792-11563740")$gene_name
features
# Out:
# [1] "Gm47034"

# %%
CoveragePlot(
  object = seurat,
  region = "9-11562792-11563740",
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  )
# Out:
# Warning message:
# “Removed 2 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %% [markdown]
# # Eps progenitors

# %%
eps_prog_regions = 
c("14-79596355-79597272",
 "12-27615808-27616636",
 "5-150823073-150823955",
 "7-136365546-136366501",
 "6-16486958-16487859")

# %%
CoveragePlot(
  object = seurat,
  region = eps_prog_regions[[1]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, eps_prog_regions[[1]])$gene_name
)
# Out:
# Warning message:
# “Removed 31 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
features=ClosestFeature(seurat, eps_prog_regions[[2]])$gene_name
features
# Out:
# [1] "Gm4166"

# %%
CoveragePlot(
  object = seurat,
  region = eps_prog_regions[[2]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
)
# Out:
# Warning message:
# “Removed 4 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = eps_prog_regions[[3]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, eps_prog_regions[[3]])$gene_name
)
# Out:
# Warning message:
# “Removed 3 rows containing missing values (geom_segment).”
# plot without title

# %%
features=ClosestFeature(seurat, eps_prog_regions[[4]])$gene_name
features
# Out:
# [1] "Gm36849"

# %%
CoveragePlot(
  object = seurat,
  region = eps_prog_regions[[4]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  
)
# Out:
# plot without title

# %%
features=ClosestFeature(seurat, eps_prog_regions[[5]])$gene_name
features
# Out:
# [1] "Gm36406"

# %%
CoveragePlot(
  object = seurat,
  region = eps_prog_regions[[5]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
)
# Out:
# plot without title

# %% [markdown]
# # Fev+ Delta

# %%
fev_delta_regions = 
c("13-63992524-63993343",
 "10-69640253-69641178",
 "10-64082077-64082994",
 "8-69030907-69031818",
 "13-34956731-34957646")

# %%
features=ClosestFeature(seurat, fev_delta_regions[[1]])$gene_name
features
# Out:
# [1] "Hsd17b3"

# %%
CoveragePlot(
  object = seurat,
  region = fev_delta_regions[[1]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  
)
# Out:
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = fev_delta_regions[[2]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, fev_delta_regions[[2]])$gene_name
)
# Out:
# Warning message:
# “Removed 870 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = fev_delta_regions[[3]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, fev_delta_regions[[3]])$gene_name
)
# Out:
# Warning message:
# “Removed 68 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = fev_delta_regions[[3]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, fev_delta_regions[[3]])$gene_name
)
# Out:
# Warning message:
# “Removed 68 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = fev_delta_regions[[4]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, fev_delta_regions[[4]])$gene_name
)
# Out:
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = fev_delta_regions[[5]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, fev_delta_regions[[5]])$gene_name
)
# Out:
# Warning message:
# “Removed 26 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %% [markdown]
# # Alpha

# %%
alpha_regions = 
c("19-60167711-60168625",
 "14-93825518-93826591",
 "3-154084552-154085465",
 "16-70767846-70768746",
 "3-17473827-17474733")

# %%
CoveragePlot(
  object = seurat,
  region = alpha_regions[[1]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, alpha_regions[[1]])$gene_name
)
# Out:
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = alpha_regions[[2]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, alpha_regions[[2]])$gene_name
)
# Out:
# Warning message:
# “Removed 29 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = alpha_regions[[3]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, alpha_regions[[3]])$gene_name
)
# Out:
# Warning message:
# “Removed 56 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
features=ClosestFeature(seurat, alpha_regions[[4]])$gene_name
features
# Out:
# [1] "D16Ertd519e"

# %%
CoveragePlot(
  object = seurat,
  region = alpha_regions[[4]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  
)
# Out:
# plot without title

# %%
features=ClosestFeature(seurat, alpha_regions[[5]])$gene_name
features
# Out:
# [1] "Gm30340"

# %%
CoveragePlot(
  object = seurat,
  region = alpha_regions[[5]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  
)
# Out:
# plot without title

# %% [markdown]
# # Beta

# %%
beta_regions = 
c("10-20505031-20505953",
 "6-6536673-6537567",
 "10-76859043-76859925",
 "18-84450439-84451317",
 "14-121888845-121889756")

# %%
CoveragePlot(
  object = seurat,
  region = beta_regions[[1]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, beta_regions[[1]])$gene_name
)
# Out:
# Warning message:
# “Removed 69 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = beta_regions[[2]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, beta_regions[[2]])$gene_name
)
# Out:
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = beta_regions[[3]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, beta_regions[[3]])$gene_name
)
# Out:
# Warning message:
# “Removed 101 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = beta_regions[[4]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, beta_regions[[4]])$gene_name
)
# Out:
# Warning message:
# “Removed 24 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

# %%
CoveragePlot(
  object = seurat,
  region = beta_regions[[5]],
  annotation = TRUE,
  peaks = TRUE,
  extend.upstream = 2000,
  extend.downstream = 2000,
  features=ClosestFeature(seurat, beta_regions[[5]])$gene_name
)
# Out:
# Warning message:
# “Removed 24 rows containing missing values (geom_segment).”
# Warning message:
# “Removed 1 rows containing missing values (geom_segment).”
# plot without title

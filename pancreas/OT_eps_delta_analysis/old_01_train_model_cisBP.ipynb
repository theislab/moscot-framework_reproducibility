# %%
import jax
from jax.config import config
config.update("jax_enable_x64", True)

# %%
import scanpy as sc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import moscot
from moscot.problems.time import TemporalProblem
import moscot.plotting as mpl
import pandas as pd
import os

sc.set_figure_params(scanpy=True, dpi=80, dpi_save=200)
                         
import mplscience

mplscience.available_styles()
mplscience.set_style(reset_current=True)
plt.rcParams['legend.scatterpoints'] = 1
# Out:
# ['default', 'despine']

# %%
output_dir = "."

# %%
adata = sc.read_h5ad("/lustre/groups/ml01/workspace/moscot_paper/pancreas/adata_processed.h5ad")

# %%
chromvar_features = pd.read_csv("/lustre/groups/ml01/workspace/moscot_paper/pancreas/cisBP_chromvar_annotations_reduced.csv")

# %%
chromvar_features.set_index("Unnamed: 0", inplace=True)

# %%
chromvar_features = chromvar_features.T

# %%
chromvar_features.head()
# Out:
# Unnamed: 0                new motif  new motif.1  new motif.2  new motif.3  \
# E14-5_AAACAGCCAACAGCCT-1   1.449150    -1.548024     0.127186    -0.401432
# E14-5_AAACAGCCAACCCTCC-1  -0.986286     3.096357     2.472101     0.594340
# E14-5_AAACAGCCACCTGTAA-1   2.217122    -0.694262    -1.776413    -0.556984
# E14-5_AAACAGCCACTAAGCC-1   1.043075     1.337077    -0.491503     1.104463
# E14-5_AAACAGCCAGGATAAC-1   0.537357    -0.343018    -1.047688    -1.379141
#
# Unnamed: 0                new motif.4  new motif.5  new motif.6  new motif.7  \
# E14-5_AAACAGCCAACAGCCT-1     5.779336    -0.047665    -0.104796     0.082138
# E14-5_AAACAGCCAACCCTCC-1     5.514991     1.100158    -0.874710    -0.670196
# E14-5_AAACAGCCACCTGTAA-1    -0.999821    -1.439918    -0.359144     0.231731
# E14-5_AAACAGCCACTAAGCC-1     5.234869    -0.295337     0.489305    -1.783421
# E14-5_AAACAGCCAGGATAAC-1     0.126564    -0.931787    -0.365652    -1.572852
#
# Unnamed: 0                new motif.8  new motif.9  ...  new motif.6004  \
# E14-5_AAACAGCCAACAGCCT-1    -0.065305    -0.163256  ...       -1.134490
# E14-5_AAACAGCCAACCCTCC-1     0.534449    -0.349137  ...       -1.157848
# E14-5_AAACAGCCACCTGTAA-1    -1.116241    -0.331855  ...        1.615487
# E14-5_AAACAGCCACTAAGCC-1    -1.110079    -0.149686  ...       -0.439479
# E14-5_AAACAGCCAGGATAAC-1    -1.259440    -1.114664  ...        0.704474
#
# Unnamed: 0                new motif.6005  new motif.6006  new motif.6007  \
# E14-5_AAACAGCCAACAGCCT-1        0.531467       -0.404171       -2.334780
# E14-5_AAACAGCCAACCCTCC-1       -1.993996        0.308834       -1.702847
# E14-5_AAACAGCCACCTGTAA-1       -0.255339       -1.269120        2.926865
# E14-5_AAACAGCCACTAAGCC-1       -0.452744       -1.027292       -2.424418
# E14-5_AAACAGCCAGGATAAC-1       -0.813751       -1.530833       -0.959602
#
# Unnamed: 0                new motif.6008  new motif.6009  new motif.6010  \
# E14-5_AAACAGCCAACAGCCT-1        0.179397       -0.388121        0.772678
# E14-5_AAACAGCCAACCCTCC-1       -1.646581        1.172381        0.286935
# E14-5_AAACAGCCACCTGTAA-1        0.709345        0.389420       -1.620937
# E14-5_AAACAGCCACTAAGCC-1       -0.645681       -0.100782        2.136637
# E14-5_AAACAGCCAGGATAAC-1       -1.077125       -1.498234        1.009304
#
# Unnamed: 0                new motif.6011  new motif.6012  new motif.6013
# E14-5_AAACAGCCAACAGCCT-1        0.357471        0.428473        0.772678
# E14-5_AAACAGCCAACCCTCC-1       -0.433321        2.500077        0.286935
# E14-5_AAACAGCCACCTGTAA-1       -1.635631       -0.787535       -1.620937
# E14-5_AAACAGCCACTAAGCC-1        0.185030        0.231816        2.136637
# E14-5_AAACAGCCAGGATAAC-1        1.857225        1.016590        1.009304
#
# [5 rows x 6014 columns]

# %%
chromvar_features["old_index"] = chromvar_features.index

# %%
def rename_index(x):
    split = x["old_index"].split("_")
    if split[0] == "E14-5":
        return split[1]+"-0"
    if split[0] == "E15-5":
        return split[1]+"-1"
    raise ValueError("Pattern does not match")

# %%
chromvar_features["index_adapted"] = chromvar_features.apply(rename_index ,axis=1)

# %%
chromvar_features.head()
# Out:
# Unnamed: 0                new motif  new motif.1  new motif.2  new motif.3  \
# E14-5_AAACAGCCAACAGCCT-1   1.449150    -1.548024     0.127186    -0.401432
# E14-5_AAACAGCCAACCCTCC-1  -0.986286     3.096357     2.472101     0.594340
# E14-5_AAACAGCCACCTGTAA-1   2.217122    -0.694262    -1.776413    -0.556984
# E14-5_AAACAGCCACTAAGCC-1   1.043075     1.337077    -0.491503     1.104463
# E14-5_AAACAGCCAGGATAAC-1   0.537357    -0.343018    -1.047688    -1.379141
#
# Unnamed: 0                new motif.4  new motif.5  new motif.6  new motif.7  \
# E14-5_AAACAGCCAACAGCCT-1     5.779336    -0.047665    -0.104796     0.082138
# E14-5_AAACAGCCAACCCTCC-1     5.514991     1.100158    -0.874710    -0.670196
# E14-5_AAACAGCCACCTGTAA-1    -0.999821    -1.439918    -0.359144     0.231731
# E14-5_AAACAGCCACTAAGCC-1     5.234869    -0.295337     0.489305    -1.783421
# E14-5_AAACAGCCAGGATAAC-1     0.126564    -0.931787    -0.365652    -1.572852
#
# Unnamed: 0                new motif.8  new motif.9  ...  new motif.6006  \
# E14-5_AAACAGCCAACAGCCT-1    -0.065305    -0.163256  ...       -0.404171
# E14-5_AAACAGCCAACCCTCC-1     0.534449    -0.349137  ...        0.308834
# E14-5_AAACAGCCACCTGTAA-1    -1.116241    -0.331855  ...       -1.269120
# E14-5_AAACAGCCACTAAGCC-1    -1.110079    -0.149686  ...       -1.027292
# E14-5_AAACAGCCAGGATAAC-1    -1.259440    -1.114664  ...       -1.530833
#
# Unnamed: 0                new motif.6007  new motif.6008  new motif.6009  \
# E14-5_AAACAGCCAACAGCCT-1       -2.334780        0.179397       -0.388121
# E14-5_AAACAGCCAACCCTCC-1       -1.702847       -1.646581        1.172381
# E14-5_AAACAGCCACCTGTAA-1        2.926865        0.709345        0.389420
# E14-5_AAACAGCCACTAAGCC-1       -2.424418       -0.645681       -0.100782
# E14-5_AAACAGCCAGGATAAC-1       -0.959602       -1.077125       -1.498234
#
# Unnamed: 0                new motif.6010  new motif.6011  new motif.6012  \
# E14-5_AAACAGCCAACAGCCT-1        0.772678        0.357471        0.428473
# E14-5_AAACAGCCAACCCTCC-1        0.286935       -0.433321        2.500077
# E14-5_AAACAGCCACCTGTAA-1       -1.620937       -1.635631       -0.787535
# E14-5_AAACAGCCACTAAGCC-1        2.136637        0.185030        0.231816
# E14-5_AAACAGCCAGGATAAC-1        1.009304        1.857225        1.016590
#
# Unnamed: 0                new motif.6013                 old_index  \
# E14-5_AAACAGCCAACAGCCT-1        0.772678  E14-5_AAACAGCCAACAGCCT-1
# E14-5_AAACAGCCAACCCTCC-1        0.286935  E14-5_AAACAGCCAACCCTCC-1
# E14-5_AAACAGCCACCTGTAA-1       -1.620937  E14-5_AAACAGCCACCTGTAA-1
# E14-5_AAACAGCCACTAAGCC-1        2.136637  E14-5_AAACAGCCACTAAGCC-1
# E14-5_AAACAGCCAGGATAAC-1        1.009304  E14-5_AAACAGCCAGGATAAC-1
#
# Unnamed: 0                       index_adapted
# E14-5_AAACAGCCAACAGCCT-1  AAACAGCCAACAGCCT-1-0
# E14-5_AAACAGCCAACCCTCC-1  AAACAGCCAACCCTCC-1-0
# E14-5_AAACAGCCACCTGTAA-1  AAACAGCCACCTGTAA-1-0
# E14-5_AAACAGCCACTAAGCC-1  AAACAGCCACTAAGCC-1-0
# E14-5_AAACAGCCAGGATAAC-1  AAACAGCCAGGATAAC-1-0
#
# [5 rows x 6016 columns]

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 9365 × 242922

# %%
endocrine_celltypes = [
    "Ngn3 low",
    "Ngn3 high",
    "Ngn3 high cycling",
    "Fev+",
    "Fev+ Alpha",
    "Fev+ Beta",
    "Fev+ Delta",
    "Eps. progenitors",
    "Alpha",
    "Beta",
    "Delta",
    "Epsilon"
]

# %%
adata.obs = adata.obs.merge(chromvar_features, left_index=True, right_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 adata.obs = adata.obs.merge(chromvar_features, left_index=True, right_index=True)
#
# File ~/miniconda3/envs/jax_gpu3/lib/python3.8/site-packages/anndata/_core/anndata.py:859, in AnnData.obs(self, value)
#     857 @obs.setter
#     858 def obs(self, value: pd.DataFrame):
# --> 859     self._set_dim_df(value, "obs")
#
# File ~/miniconda3/envs/jax_gpu3/lib/python3.8/site-packages/anndata/_core/anndata.py:798, in AnnData._set_dim_df(self, value, attr)
#     796 if not isinstance(value, pd.DataFrame):
#     797     raise ValueError(f"Can only assign pd.DataFrame to {attr}.")
# --> 798 value_idx = self._prep_dim_index(value.index, attr)
#     799 if self.is_view:
#     800     self._init_as_actual(self.copy())
#
# File ~/miniconda3/envs/jax_gpu3/lib/python3.8/site-packages/anndata/_core/anndata.py:810, in AnnData._prep_dim_index(self, value, attr)
#     805 """Prepares index to be uses as obs_names or var_names for AnnData object.AssertionError
#     806
#     807 If a pd.Index is passed, this will use a reference, otherwise a new index object is created.
#     808 """
#     809 if self.shape[attr == "var"] != len(value):
# --> 810     raise ValueError(
#     811         f"Length of passed value for {attr}_names is {len(value)}, but this AnnData has shape: {self.shape}"
#     812     )
#     813 if isinstance(value, pd.Index) and not isinstance(
#     814     value.name, (str, type(None))
#     815 ):
#     816     raise ValueError(
#     817         f"AnnData expects .{attr}.index.name to be a string or None, "
#     818         f"but you passed a name of type {type(value.name).__name__!r}"
#     819     )
#
# ValueError: Length of passed value for obs_names is 0, but this AnnData has shape: (9365, 242922)

# %% [markdown]
# # Heat kernel distances

# %%
import pygsp

# %%
sc.pp.neighbors(adata, use_rep="X_multi_vi", key_added="multi_vi", n_neighbors=30)

# %%
cell_ids_source = adata[adata.obs["time"]==14.5].obs_names
cell_ids_target = adata[adata.obs["time"]==15.5].obs_names

# %%
assert (adata.obs.iloc[:(len(cell_ids_source))].index == cell_ids_source).all()
assert (adata.obs.iloc[(len(cell_ids_source)):].index == cell_ids_target).all()

# %%
G = pygsp.graphs.Graph(adata.obsp["multi_vi_connectivities"])

# %%
G.estimate_lmax()

# %%
filt = pygsp.filters.Heat(G, tau=100)
diffusion_distances = filt.filter(np.eye(len(adata)))
custom_cost = pd.DataFrame(data=-np.log(diffusion_distances[:len(cell_ids_source), len(cell_ids_source):].copy())+1e-15, index=cell_ids_source, columns=cell_ids_target)

# %%
tp0 = TemporalProblem(adata)
tp0 = tp0.prepare("time", joint_attr="X_multi_vi")

# %%
tp0[14.5, 15.5].set_xy(custom_cost, tag="cost_matrix")

# %%
tp0 = tp0.solve(max_iterations=1e8)

# %%
tp0.save("/lustre/groups/ml01/workspace/moscot_paper/pancreas/", file_prefix="cisBP", overwrite=True)

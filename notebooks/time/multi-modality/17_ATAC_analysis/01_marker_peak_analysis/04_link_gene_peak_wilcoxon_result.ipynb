# %%
library(anndata)
library(Signac)
library(Seurat)
library(ggplot2)
library(tidyverse)
# Out:
# Warning message:
# “package ‘Signac’ was built under R version 4.2.3”
# Signac built for for SeuratObject v4 was just loaded with SeuratObject
# v5; disabling v5 assays and validation routines, and ensuring assays
# work in strict v3/v4 compatibility mode
#
# Warning message:
# “package ‘Seurat’ was built under R version 4.2.3”
# Attaching SeuratObject
#
# ‘SeuratObject’ was built with package ‘Matrix’ 1.6.3 but the current
# version is 1.6.4; it is recomended that you reinstall ‘SeuratObject’ as
# the ABI for ‘Matrix’ may have changed
#
# Seurat v4 was just loaded with SeuratObject v5; disabling v5 assays and
# validation routines, and ensuring assays work in strict v3/v4
# compatibility mode
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.2.3”
# Warning message:
# “package ‘tidyverse’ was built under R version 4.2.3”
# Warning message:
# “package ‘tibble’ was built under R version 4.2.3”
# Warning message:
# “package ‘tidyr’ was built under R version 4.2.3”
# ...

# %%
seurat <- readRDS("/lustre/groups/ml01/workspace/moscot_paper/pancreas_revision/seurat_endocrine_with_links_long_range.rds")

# %% [markdown]
# ## Fev+ Delta, 0

# %%
markers_fev_delta0 <- read.csv("/lustre/groups/ml01/workspace/moscot_paper/pancreas_revision/marker_peak_analysis/diff_peaks_signac_fev_delta0.csv")

# %%
range <- markers_fev_delta0$X[[1]]
range
# Out:
# [1] "9-16183628-16184537"

# %%
Links(seurat)[Links(seurat)$peak==range]
# Out:
# GRanges object with 0 ranges and 5 metadata columns:
#    seqnames    ranges strand |     score        gene        peak    zscore
#       <Rle> <IRanges>  <Rle> | <numeric> <character> <character> <numeric>
#       pvalue
#    <numeric>
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %%
range <- markers_fev_delta0$X[[2]]
range
# Out:
# [1] "14-27371461-27372357"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 3

# %%
table[order(table$score), ]
# Out:
# GRanges object with 3 ranges and 5 metadata columns:
#       seqnames            ranges strand |     score        gene
#          <Rle>         <IRanges>  <Rle> | <numeric> <character>
#   [1]       14 27371909-33214026      * | 0.0507437    Arhgap22
#   [2]       14 27371909-31217860      * | 0.0527504      Sema3g
#   [3]       14 24014491-27371909      * | 0.0566739      Kcnma1
#                       peak    zscore      pvalue
#                <character> <numeric>   <numeric>
#   [1] 14-27371461-27372357   4.73660 1.08666e-06
#   [2] 14-27371461-27372357   2.30214 1.06637e-02
#   [3] 14-27371461-27372357   3.80915 6.97224e-05
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %%
range <- markers_fev_delta0$X[[3]]
range
# Out:
# [1] "4-53066690-53067639"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 0

# %%
range <- markers_fev_delta0$X[[4]]
range
# Out:
# [1] "11-83597993-83598927"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 4

# %%
table[order(table$score), ]
# Out:
# GRanges object with 4 ranges and 5 metadata columns:
#       seqnames            ranges strand |      score        gene
#          <Rle>         <IRanges>  <Rle> |  <numeric> <character>
#   [1]       11 83598460-86757565      * | -0.0519194        Cltc
#   [2]       11 83598460-87074062      * |  0.0524030       Gdpd1
#   [3]       11 83598460-87737552      * |  0.0561531      Supt4a
#   [4]       11 78183584-83598460      * |  0.0655262      Rpl23a
#                       peak    zscore     pvalue
#                <character> <numeric>  <numeric>
#   [1] 11-83597993-83598927  -2.06812 0.01931432
#   [2] 11-83597993-83598927   2.07332 0.01907144
#   [3] 11-83597993-83598927   2.95762 0.00155013
#   [4] 11-83597993-83598927   1.81931 0.03443200
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %%
range <- markers_fev_delta0$X[[5]]
range
# Out:
# [1] "9-111514463-111515369"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 3

# %%
table[order(table$score), ]
# Out:
# GRanges object with 3 ranges and 5 metadata columns:
#       seqnames              ranges strand |      score        gene
#          <Rle>           <IRanges>  <Rle> |  <numeric> <character>
#   [1]        9 111514916-120539818      * | -0.0867132      Entpd3
#   [2]        9 107635367-111514916      * | -0.0575600       Gnai2
#   [3]        9 111514916-121495694      * |  0.0992655         Cck
#                        peak    zscore      pvalue
#                 <character> <numeric>   <numeric>
#   [1] 9-111514463-111515369  -1.75176 0.039907914
#   [2] 9-111514463-111515369  -1.95469 0.025309772
#   [3] 9-111514463-111515369   3.35469 0.000397273
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %%
range <- markers_fev_delta0$X[[6]]
range
# Out:
# [1] "2-116685405-116686332"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 0

# %% [markdown]
# ## Fev+ Delta,1

# %%
markers_fev_delta1 <- read.csv("/lustre/groups/ml01/workspace/moscot_paper/pancreas_revision/marker_peak_analysis/diff_peaks_signac_fev_delta1.csv")

# %%
markers_fev_delta0
# Out:
#       X                      p_val        avg_log2FC pct.1 pct.2 p_val_adj
# 1     9-16183628-16184537    9.937382e-16  2.7154577 0.112 0.018 2.501000e-10
# 2     14-27371461-27372357   7.270499e-14  1.7486304 0.246 0.076 1.829810e-08
# 3     4-53066690-53067639    2.028388e-12  1.9322776 0.179 0.048 5.104967e-07
# 4     11-83597993-83598927   2.811053e-12  1.6257943 0.269 0.094 7.074746e-07
# 5     9-111514463-111515369  9.483508e-12  1.7704466 0.209 0.064 2.386771e-06
# 6     2-116685405-116686332  1.678574e-11  1.8505091 0.179 0.050 4.224568e-06
# 7     10-94567697-94568589   2.021331e-11  1.6435373 0.231 0.077 5.087205e-06
# 8     5-146260706-146261622  2.222854e-11 -0.8264146 0.619 0.810 5.594390e-06
# 9     6-104600722-104601637  2.712109e-11  1.8728105 0.172 0.048 6.825728e-06
# 10    3-109737746-109738667  3.059801e-11  2.0418358 0.149 0.038 7.700785e-06
# 11    9-98279919-98280848    3.939034e-11  1.1960535 0.396 0.185 9.913603e-06
# ...

# %%
range <- markers_fev_delta1$X[[1]]
range
# Out:
# [1] "9-11562788-11563740"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 0

# %%
range <- markers_fev_delta1$X[[2]]
range
# Out:
# [1] "13-34956729-34957647"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 0

# %%
range <- markers_fev_delta1$X[[3]]
range
# Out:
# [1] "2-135719090-135720017"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 2

# %%
table[order(table$score), ]
# Out:
# GRanges object with 2 ranges and 5 metadata columns:
#       seqnames              ranges strand |      score        gene
#          <Rle>           <IRanges>  <Rle> |  <numeric> <character>
#   [1]        2 132781278-135719554      * | -0.0637096        Chgb
#   [2]        2 135659011-135719554      * |  0.0779370       Plcb4
#                        peak    zscore      pvalue
#                 <character> <numeric>   <numeric>
#   [1] 2-135719090-135720017  -1.85583 3.17392e-02
#   [2] 2-135719090-135720017   3.78572 7.66326e-05
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# ## Epsilon progenitors

# %%
markers_eps_prog <- read.csv("/lustre/groups/ml01/workspace/moscot_paper/pancreas_revision/marker_peak_analysis/diff_peaks_signac_eps_prog.csv")

# %%
range <- markers_eps_prog$X[[1]]
range
# Out:
# [1] "10-64082075-64082998"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 2

# %%
table[order(table$score), ]
# Out:
# GRanges object with 2 ranges and 5 metadata columns:
#       seqnames            ranges strand |     score        gene
#          <Rle>         <IRanges>  <Rle> | <numeric> <character>
#   [1]       10 63430098-64082537      * |  0.181818      Ctnna3
#   [2]       10 64082537-64090277      * |  0.200008      Lrrtm3
#                       peak    zscore      pvalue
#                <character> <numeric>   <numeric>
#   [1] 10-64082075-64082998   12.2500 8.40486e-35
#   [2] 10-64082075-64082998   14.4806 8.02976e-48
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %%
range <- markers_eps_prog$X[[2]]
range
# Out:
# [1] "14-27371461-27372357"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 3

# %%
table[order(table$score), ]
# Out:
# GRanges object with 3 ranges and 5 metadata columns:
#       seqnames            ranges strand |     score        gene
#          <Rle>         <IRanges>  <Rle> | <numeric> <character>
#   [1]       14 27371909-33214026      * | 0.0507437    Arhgap22
#   [2]       14 27371909-31217860      * | 0.0527504      Sema3g
#   [3]       14 24014491-27371909      * | 0.0566739      Kcnma1
#                       peak    zscore      pvalue
#                <character> <numeric>   <numeric>
#   [1] 14-27371461-27372357   4.73660 1.08666e-06
#   [2] 14-27371461-27372357   2.30214 1.06637e-02
#   [3] 14-27371461-27372357   3.80915 6.97224e-05
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %% [markdown]
# # Fev+ Delta

# %%
markers_fev_delta <- read.csv("/lustre/groups/ml01/workspace/moscot_paper/pancreas_revision/marker_peak_analysis/diff_peaks_signac_fev_delta.csv")

# %%
range <- markers_fev_delta$X[[1]]
range
# Out:
# [1] "2-135719090-135720017"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 2

# %%
table[order(table$score), ]
# Out:
# GRanges object with 2 ranges and 5 metadata columns:
#       seqnames              ranges strand |      score        gene
#          <Rle>           <IRanges>  <Rle> |  <numeric> <character>
#   [1]        2 132781278-135719554      * | -0.0637096        Chgb
#   [2]        2 135659011-135719554      * |  0.0779370       Plcb4
#                        peak    zscore      pvalue
#                 <character> <numeric>   <numeric>
#   [1] 2-135719090-135720017  -1.85583 3.17392e-02
#   [2] 2-135719090-135720017   3.78572 7.66326e-05
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

# %%
range <- markers_fev_delta$X[[2]]
range
# Out:
# [1] "9-11562788-11563740"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 0

# %%
range <- markers_fev_delta$X[[3]]
range
# Out:
# [1] "13-34956729-34957647"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 0

# %%
range <- markers_fev_delta$X[[4]]
range
# Out:
# [1] "10-64082075-64082998"

# %%
table <- Links(seurat)[Links(seurat)$peak==range]
length(table)
# Out:
# [1] 2

# %%
table[order(table$score), ]
# Out:
# GRanges object with 2 ranges and 5 metadata columns:
#       seqnames            ranges strand |     score        gene
#          <Rle>         <IRanges>  <Rle> | <numeric> <character>
#   [1]       10 63430098-64082537      * |  0.181818      Ctnna3
#   [2]       10 64082537-64090277      * |  0.200008      Lrrtm3
#                       peak    zscore      pvalue
#                <character> <numeric>   <numeric>
#   [1] 10-64082075-64082998   12.2500 8.40486e-35
#   [2] 10-64082075-64082998   14.4806 8.02976e-48
#   -------
#   seqinfo: 21 sequences from an unspecified genome; no seqlengths

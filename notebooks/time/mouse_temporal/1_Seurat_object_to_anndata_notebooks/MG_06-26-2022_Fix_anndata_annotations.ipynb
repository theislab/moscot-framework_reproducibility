# %% [markdown]
# # Running moscot

# %% [markdown]
# This notebook depends on data generated by 'MG_06-26-2022_Seurat_object_to_anndata'. In that notebook, .RDS-Seurat objects were transformed into anndata objects. However, some annotations are not tranfered correctly from Exp@meta.data to adata.obs, hence the annotations are added manually here

# %%
import numpy as np
import anndata
import pandas as pd
import scanpy as sc
import scipy

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -------------------------
# absl-py                       1.1.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# altair                        4.2.0
# anndata                       0.8.0
# anyio                         3.6.1
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# asttokens                     2.0.5
# async-timeout                 4.0.2
# attrs                         21.4.0
# Babel                         2.10.3
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# beautifulsoup4                4.11.1
# biomart                       0.9.2
# bleach                        5.0.1
# blinker                       1.5
# brotlipy                      0.7.0
# cachetools                    5.2.0
# cellrank                      1.5.1
# certifi                       2022.6.15
# cffi                          1.15.1
# charset-normalizer            2.1.0
# chex                          0.1.3
# click                         8.1.3
# colorama                      0.4.5
# commonmark                    0.9.1
# cryptography                  37.0.4
# cuda-python                   11.7.1
# cycler                        0.11.0
# Cython                        0.29.32
# debugpy                       1.6.0
# decorator                     5.1.1
# defusedxml                    0.7.1
# dm-tree                       0.1.7
# dnspython                     2.2.1
# docopt                        0.6.2
# docrep                        0.3.2
# entrypoints                   0.4
# et-xmlfile                    1.1.0
# etils                         0.6.0
# executing                     0.8.3
# fastjsonschema                2.16.1
# flatbuffers                   2.0
# flax                          0.5.2
# flit_core                     3.7.1
# fonttools                     4.34.4
# frozenlist                    1.3.1
# fsspec                        2022.7.1
# future                        0.18.2
# gitdb                         4.0.9
# GitPython                     3.1.27
# google-auth                   2.10.0
# google-auth-oauthlib          0.4.6
# grpcio                        1.47.0
# h5py                          3.7.0
# idna                          3.3
# igraph                        0.9.11
# importlib-metadata            4.11.4
# importlib-resources           5.8.0
# ipykernel                     6.15.1
# ipython                       8.4.0
# ipython-genutils              0.2.0
# ipywidgets                    7.7.1
# jax                           0.3.14
# jaxlib                        0.3.14+cuda11.cudnn82
# jedi                          0.18.1
# Jinja2                        3.0.3
# joblib                        1.1.0
# json5                         0.9.5
# jsonpickle                    1.5.2
# jsonschema                    4.7.2
# jupyter-client                7.3.4
# jupyter-core                  4.10.0
# jupyter-server                1.18.1
# jupyterlab                    3.4.3
# jupyterlab-pygments           0.2.2
# jupyterlab-server             2.15.0
# jupyterlab-widgets            1.1.1
# kiwisolver                    1.4.4
# leidenalg                     0.8.10
# llvmlite                      0.39.0
# loompy                        3.0.7
# Markdown                      3.4.1
# MarkupSafe                    2.1.1
# matplotlib                    3.5.2
# matplotlib-inline             0.1.3
# memory-profiler               0.61.0
# mistune                       0.8.4
# mkl-fft                       1.3.1
# mkl-random                    1.2.2
# mkl-service                   2.4.0
# mplscience                    0.0.5
# msgpack                       1.0.4
# mudata                        0.2.0
# multidict                     6.0.2
# multipledispatch              0.6.0
# munch                         2.5.0
# natsort                       8.1.0
# nbclassic                     0.4.3
# nbclient                      0.6.6
# nbconvert                     6.5.0
# nbformat                      5.4.0
# nest-asyncio                  1.5.5
# networkx                      2.8.4
# notebook                      6.4.12
# notebook-shim                 0.1.0
# numba                         0.56.0
# numpy                         1.22.4
# numpy-groupies                0.9.17
# numpy-indexed                 0.3.7
# numpyro                       0.10.0
# oauthlib                      3.2.0
# openpyxl                      3.0.10
# opt-einsum                    3.3.0
# optax                         0.1.3
# ott-jax                       0.2.4.dev359+gae97a3d
# packaging                     21.3
# palmerpenguins                0.1.4
# pandas                        1.4.3
# pandocfilters                 1.5.0
# parso                         0.8.3
# patsy                         0.5.2
# pexpect                       4.8.0
# pickleshare                   0.7.5
# Pillow                        9.2.0
# pip                           22.1.2
# plotly                        5.10.0
# POT                           0.8.2
# progressbar2                  4.2.0
# prometheus-client             0.14.1
# prompt-toolkit                3.0.30
# protobuf                      3.19.4
# psutil                        5.9.1
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py-cpuinfo                    9.0.0
# pyarrow                       9.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycparser                     2.21
# pydeck                        0.8.0b3
# pyDeprecate                   0.3.2
# pygam                         0.8.0
# Pygments                      2.12.0
# pygpcca                       1.0.4
# PyGSP                         0.5.1
# pymongo                       4.3.3
# Pympler                       1.0.1
# pynndescent                   0.5.7
# pyOpenSSL                     22.0.0
# pyparsing                     3.0.9
# pyro-api                      0.1.2
# pyro-ppl                      1.8.1
# pyrsistent                    0.18.1
# PySocks                       1.7.1
# python-dateutil               2.8.2
# python-utils                  3.4.5
# pytorch-lightning             1.6.5
# pytz                          2022.1
# pytz-deprecation-shim         0.1.0.post0
# PyYAML                        6.0
# pyzmq                         23.2.0
# reload                        0.9
# requests                      2.28.1
# requests-oauthlib             1.3.1
# rich                          11.2.0
# rsa                           4.9
# sacred                        0.8.2
# scanpy                        1.9.1
# scikit-learn                  1.1.1
# scikit-misc                   0.1.4
# scipy                         1.8.1
# scvelo                        0.2.4
# scvi-tools                    0.17.1
# seaborn                       0.11.2
# seml                          0.3.7
# semver                        2.13.0
# Send2Trash                    1.8.0
# session-info                  1.0.0
# setuptools                    63.2.0
# six                           1.16.0
# smmap                         5.0.0
# sniffio                       1.2.0
# soupsieve                     2.3.1
# stack-data                    0.3.0
# statsmodels                   0.13.2
# stdlib-list                   0.8.0
# streamlit                     1.13.0
# tenacity                      8.1.0
# tensorboard                   2.10.0
# tensorboard-data-server       0.6.1
# tensorboard-plugin-wit        1.8.1
# terminado                     0.15.0
# texttable                     1.6.4
# threadpoolctl                 3.1.0
# tinycss2                      1.1.1
# toml                          0.10.2
# toolz                         0.12.0
# torch                         1.11.0+cu113
# torchmetrics                  0.9.3
# torchvision                   0.12.0+cu113
# tornado                       6.2
# tqdm                          4.64.0
# traitlets                     5.3.0
# typing_extensions             4.3.0
# tzdata                        2022.4
# tzlocal                       4.2
# umap-learn                    0.5.3
# urllib3                       1.26.10
# utils                         1.0.1
# validators                    0.20.0
# watchdog                      2.1.9
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              1.3.3
# Werkzeug                      2.2.2
# wheel                         0.37.1
# widgetsnbextension            3.6.1
# wot                           1.0.8.post3.dev8+gca5e94f
# wrapt                         1.14.1
# yarl                          1.8.1
# zip-files                     0.4.1
# zipp                          3.8.0

# %%
Path="/home/icb/manuel.gander/moscotTime_Reproducibility/Data"
ts=['E3.5', 'E4.5', 'E5.25', 'E5.5', 'E6.25', 'E6.5', 'E6.75', 'E7.0', 'E7.25', 'E7.5', 'E7.75', 'E8.0', 'E8.25', 'E8.5a', 'E8.5b', 'E9.5', 'E10.5', 'E11.5', 'E12.5', 'E13.5']

# %% [markdown]
# # Fix annotation

# %% [markdown]
# Some annotations are incompletely tranfered, e.g. the cell types are transfered as numbers instead of their names ('E7:Primitve erythroid cells). This is fixed here. Additionally, the ENSEMBLE gene names are translated into gene symbols for downstream processes.

# %%
#  This dictionary to translate Ensemble gene names into gene symbols was was created using biomart, see
###  Reproducibility_TOME/Notebooks/RDS_to_anndata/MG_03-31-2022_Ensemble_to_gene_symbol.ipynb

D=np.load(f'{Path}/Miscellaneous/ENS_to_genes.npy', allow_pickle=True)
Gene_Dict = dict(enumerate(D.flatten(), 1))[1]

# %% [markdown]
# ### See, columns do not contain cell state annotation

# %%
i=0
ts0=ts[i]
print(ts0)
adata=sc.read(f"{Path}/anndatas/Initial_anndatas/adata_{ts0}.h5ad")
# Out:
# E3.5

# %%
adata.obs
# Out:
#                                        orig.ident  nCount_RNA  nFeature_RNA  \
# E3.5_P8_Cell2_embryo1_single                    0    823281.0          5049
# E3.5_P8_Cell3_embryo2_single                    0    752208.0          5865
# E3.5_P8_Cell5_embryo3_single                    0    696715.0          5390
# E3.5_P8_Cell7_embryo4_single                    0   1365291.0          4028
# E3.5_P8_Cell22_embryo5_single                   0   1111620.0          4812
# ...                                           ...         ...           ...
# E3.5_P11.P6.P10_cell185_embryo_single           0    931741.0          5377
# E3.5_P11.P6.P10_cell186_embryo_single           0    579382.0          6413
# E3.5_P11.P6.P10_cell187_embryo_single           0    464591.0          3733
# E3.5_P11.P6.P10_cell189_embryo_single           0    557666.0          4388
# E3.5_P11.P6.P10_cell190_embryo_single           0    773317.0          4577
#
#                                        sample  day  group  cell_state  \
# E3.5_P8_Cell2_embryo1_single               10    0  351.0           0
# E3.5_P8_Cell3_embryo2_single               11    0  351.0           0
# E3.5_P8_Cell5_embryo3_single               12    0  351.0           0
# E3.5_P8_Cell7_embryo4_single               18    0  351.0           0
# E3.5_P8_Cell22_embryo5_single               9    0  351.0           0
# ...                                       ...  ...    ...         ...
# E3.5_P11.P6.P10_cell185_embryo_single       4    0  351.0           0
# E3.5_P11.P6.P10_cell186_embryo_single       5    0  351.0           0
# E3.5_P11.P6.P10_cell187_embryo_single       6    0  351.0           0
# E3.5_P11.P6.P10_cell189_embryo_single       7    0  351.0           0
# E3.5_P11.P6.P10_cell190_embryo_single       8    0  351.0           0
#
#                                        cell_type
# E3.5_P8_Cell2_embryo1_single                   0
# E3.5_P8_Cell3_embryo2_single                   0
# E3.5_P8_Cell5_embryo3_single                   0
# E3.5_P8_Cell7_embryo4_single                   0
# E3.5_P8_Cell22_embryo5_single                  0
# ...                                          ...
# E3.5_P11.P6.P10_cell185_embryo_single          0
# E3.5_P11.P6.P10_cell186_embryo_single          0
# E3.5_P11.P6.P10_cell187_embryo_single          0
# E3.5_P11.P6.P10_cell189_embryo_single          0
# E3.5_P11.P6.P10_cell190_embryo_single          0
#
# [90 rows x 8 columns]

# %% [markdown]
# # Scripts

# %%
def add_data_generator(adata, ts0):
    # Identify study that created the data

    z=np.full(len(adata), '___________________')
    for i in range(0, len(adata)):
        a=adata.obs['cellID'][i]
        if a[2]=='.':
            z[i]='Mohammed'
        elif a[:2]=='EB':
            z[i]='Cheng'
        elif a[:4]=='cell':
            z[i]='Pijuan'
        elif a[0]=='P':
            z[i]='Qiu'
        elif a[:4]=='sci3':
            z[i]='Cao'
        else:
            # In case this happens, the data generator study could not be identified using cellID. In that case,
            # the adata.obs['origin'] will be corrupt!!!
            print(f'error: for time point={ts0}, i={i} there has been a problem with origin identifier')
    adata.obs['origin']=z
    return(adata)

# %%
def ENSEMBLE_name_to_gene_symbol(adata, Gene_Dict):
    #############           Transfrom ENSEMBLE names into gene symbols              ##########################

    # This asigns each ENSEMBLE name it's gene name. If the corresponding gene name is not found, then the
    # ENSEMBLE name is added in the gene name row
    
    ENS=[a for a in adata.var_names].copy()
    k=0
    l=len(ENS)
    genes=np.full(l, '_______________________________-')
    for i in range(0,l):
        if ENS[i] in Gene_Dict.keys() and Gene_Dict[f'{ENS[i]}']!='':
            genes[i]=Gene_Dict[f'{ENS[i]}']
        else:
            genes[i]=ENS[i]
            k=k+1
            
    if i==0:
        print(f'{k} out of {l} Ensemble IDs were not assigned a gene name')
    adata.var['gene_names']=genes
    return(adata)

# %%
def fix_annotation(ts0, Gene_Dict):
    adata=sc.read(f"{Path}/anndatas/Initial_anndatas/adata_{ts0}.h5ad")
    adata.X=scipy.sparse.csr_matrix(adata.X, dtype=np.float32)

    adata=sc.read(f"{Path}/anndatas/Initial_anndatas/adata_{ts0}.h5ad")
    adata.X=scipy.sparse.csr_matrix(adata.X, dtype=np.float32)

    ######  Fix annotations using Seurat-metadata               ################################################
    meta=pd.read_csv(f"{Path}/metadata/meta_{ts0}.csv", sep= ",")
    
    # Check if cells are ordered the same, was the case for all time points
    if [a for a in adata.obs.index]==[a for a in meta['Unnamed: 0']]:
        pass
    else:
        print('Error: cells are not ordered the same!!!')

    # Reconstruct the annotations using the Seurat-Metadata
    del adata.obs
    adata.obs['cellID']=list(meta['Unnamed: 0'])

    # For day 8.5 Qiu et al created an additional data set
    if ts0=='E8.5a' or ts0=='E8.5b':
        a=8.5
        adata.obs['day']=a
    else:
        adata.obs['day']=float(ts0[1:])

    adata.obs['cell_state']=list(meta['cell_state'])
    adata.obs['cell_type']=list(meta['cell_type'])
    adata.obs['group']=list(meta['group'])
    adata.obs['sample']=list(meta['sample'])
    
    adata=add_data_generator(adata, ts0)
    adata=ENSEMBLE_name_to_gene_symbol(adata, Gene_Dict)

    
    # I added this to remove a strange indexing error
    adata.__dict__['_raw'].__dict__['_var'] = adata.__dict__['_raw'].__dict__['_var'].rename(columns={'_index': 'features'})
    
    adata.raw = adata
    
    # Log-normalize the expression
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    return(adata)

# %% [markdown]
# # Loop

# %%
for i in range(20):
    ts0=ts[i]
    print(ts0)
    
    adata=fix_annotation(ts0, Gene_Dict)

    adata.write(f"{Path}/anndatas/adata_{ts0}.h5ad", compression='gzip')
# Out:
# E3.5
# E4.5
# E5.25
# E5.5
# E6.25
# E6.5
# E6.75
# E7.0
# E7.25
# E7.5
# E7.75
# E8.0
# E8.25
# E8.5a
# E8.5b
# E9.5
# E10.5
# E11.5
# E12.5
# E13.5

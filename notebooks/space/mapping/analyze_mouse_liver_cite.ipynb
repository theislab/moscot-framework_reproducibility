# %%
import scanpy as sc
from pathlib import Path
import pandas as pd
from muon import prot as pt
from muon import MuData
import muon as mu
import numpy as np

# %load_ext autoreload
# %autoreload 2
# %load_ext lab_black

path_data = Path("/Users/giovanni.palla/Datasets/moscot")

# %%
adata_sc = sc.read(path_data / "adata_sc.h5ad")
adata_p = sc.read(path_data / "adata_cite.h5ad")
adata_p.layers["counts"] = adata_p.X.copy()

# %%
sc.pl.umap(adata_sc, color="annot")

# %%
# adata_sc.obs

# %%
pt.pp.clr(adata_p)
# Out:
# /Users/giovanni.palla/miniconda3/envs/moscot/lib/python3.8/site-packages/muon/_prot/preproc.py:214: UserWarning: adata.X is sparse but not in CSC format. Converting to CSC.
#   warn("adata.X is sparse but not in CSC format. Converting to CSC.")

# %%
sc.pp.pca(adata_p)
sc.pp.neighbors(adata_p)
sc.tl.umap(adata_p)
# Out:
# OMP: Info #273: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
np.testing.assert_array_equal(
    adata_sc[adata_sc.obs.typeSample == "citeSeq"].obs_names, adata_p.obs_names
)

# %%
adata_sc = adata_sc[adata_sc.obs.typeSample == "citeSeq"].copy()
adata_p.obs["annot"] = adata_sc.obs["annot"].values.copy()

# %%
sc.pl.umap(adata_p, color="annot")

# %%
adata_p.var_names
# Out:
# Index(['CLEC4F', 'IgG1_Rat_l', 'VSIG4', 'Ly6C', 'CD366', 'CD54', 'CD206',
#        'CD5', 'CD62P', 'Ly6G',
#        ...
#        'IgG1_Mouse_k', 'CD309_A0554', 'IgG2b_Mouse_k', 'CD204', 'CD64',
#        'CD223', 'CD28', 'CD135', 'CD122', 'Notch'],
#       dtype='object', length=103)

# %%
mdata = mu.MuData(
    {"rna": adata_sc[:, adata_sc.var.highly_variable].copy(), "prot": adata_p},
    feature_types_names={"Gene Expression": "rna", "Antibody Capture": "prot"},
)

# %%
adata_sc[:, adata_sc.var.highly_variable].shape
# Out:
# (91040, 5000)

# %%
sc.pp.pca(adata_sc)
sc.pp.pca(adata_p)

# %%
adata_sc.obsm["joint_pca"] = (
    adata_sc.obsm["X_pca"].copy() + adata_p.obsm["X_pca"].copy()
)

# %%
sc.pl.embedding(adata_sc, basis="joint_pca", color="annot")

# %%
adata_sc.write(path_data / "adata_sc_processed.h5ad")
adata_p.write(path_data / "adata_cite_processed.h5ad")

# %%
# mu.tl.mofa(mdata)
# Out:
#         #########################################################
#         ###           __  __  ____  ______                    ###
#         ###          |  \/  |/ __ \|  ____/\    _             ###
#         ###          | \  / | |  | | |__ /  \ _| |_           ###
#         ###          | |\/| | |  | |  __/ /\ \_   _|          ###
#         ###          | |  | | |__| | | / ____ \|_|            ###
#         ###          |_|  |_|\____/|_|/_/    \_\              ###
#         ###                                                   ###
#         #########################################################
#
#
#
# Loaded view='rna' group='group1' with N=91040 samples and D=5000 features...
# Loaded view='prot' group='group1' with N=91040 samples and D=103 features...
#
#
# Warning: 111 features(s) in view 0 have zero variance, consider removing them before training the model...
#
# Model options:
# - Automatic Relevance Determination prior on the factors: True
# - Automatic Relevance Determination prior on the weights: True
# - Spike-and-slab prior on the factors: False
# - Spike-and-slab prior on the weights: True
# Likelihoods:
# - View 0 (rna): gaussian
# - View 1 (prot): gaussian
#
#
#
#
# ######################################
# ## Training the model with seed 1 ##
# ######################################

# %%
# Out:
# 0.0

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from zipfile import ZipFile
from typing import BinaryIO

import anndata
import pandas as pd
import numpy as np
from scipy import sparse


def read_mtx_from_stream(stream) -> sparse.csr_matrix:
    curline = stream.readline()
    while curline.startswith("%"):
        curline = stream.readline()
    n, m, _ = (int(x) for x in curline[:-1].split(" "))

    max_int32 = np.iinfo(np.int32).max
    if n > max_int32 or m > max_int32:
        coord_dtype = np.int64
    else:
        coord_dtype = np.int32

    data = pd.read_csv(
        stream,
        sep=r"\s+",
        header=None,
        dtype={0: coord_dtype, 1: coord_dtype, 2: np.float32},
    )
    mtx = sparse.csr_matrix((data[2], (data[1] - 1, data[0] - 1)), shape=(m, n))
    return mtx

# %%
mtx_data_info = path_mtx / "matrix.mtx"
with open(mtx_data_info, "r") as f:
    expr = read_mtx_from_stream(f)

# %%
barcodes = pd.read_csv(path_mtx / "barcodes.tsv.gz", header=None)
features = pd.read_csv(path_mtx / "features.tsv.gz", header=None)

# %%
from anndata import AnnData

adata = AnnData(
    expr,
    obs=pd.DataFrame(index=barcodes[0].values),
    var=pd.DataFrame(index=features[0].values),
)

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# Index: [Xkr4, Gm1992, Gm37381, Rp1, Sox17, Gm37323, Mrpl15, Lypla1, Gm37988, Tcea1, Rgs20, Gm16041, Atp6v1h, Oprk1, Npbwr1, Rb1cc1, 4732440D04Rik, Alkal1, St18, Pcmtd1, Gm26901, Gm30414, Sntg1, Rrs1, Adhfe1, 3110035E14Rik, Gm29520, Mybl1, Vcpip1, 1700034P13Rik, Sgk3, Mcmdc2, Snhg6, Tcf24, Ppp1r42, Gm15818, Cops5, Cspp1, Arfgef1, Cpa6, Prex2, A830018L16Rik, Gm17644, Gm29663, Sulf1, Slco5a1, Gm29283, Prdm14, Ncoa2, Gm29570, Tram1, Lactb2, Xkr9, Eya1, Gm9947, Msc, Trpa1, Kcnb2, Terf1, Sbspon, 4930444P10Rik, Rpl7, Rdh10, Gm28095, Stau2, Gm7568, Ube2w, Eloc, D030040B21Rik, Tmem70, Ly96, Gm28376, Jph1, Gm28783, Gdap1, Gm28784, Pi15, Gm28154, Gm16070, Crispld1, Gm28153, Crisp4, Defb18, Defb41, Gm15825, Tfap2d, Tfap2b, Gm28340, Pkhd1, 4930486I03Rik, Gm28653, Il17a, Il17f, Mcm3, Gm28065, 6720483E21Rik, Paqr8, Efhc1, Tram2, Gm28287, ...]
#
# [31053 rows x 0 columns]

# %%
adata_orig = adata.copy()

# %%
clusters = pd.read_csv("/Users/giovanni.palla/Datasets/moscot/annot_mouseStStAll.csv")
clusters
# Out:
#            UMAP_1    UMAP_2  cluster        annot  sample  \
# 0       10.199693 -7.500118       21      T cells  CISE12
# 1       12.429611 -5.372781       11      T cells  CISE12
# 2       14.550602 -2.247851       26        ILC1s  CISE12
# 3       11.260082 -5.692209       11      T cells  CISE12
# 4       13.879457 -1.479918       26        ILC1s  CISE12
# ...           ...       ...      ...          ...     ...
# 185889   7.300422 -5.189817       19  Neutrophils    CS16
# 185890   5.629435 -6.119583       19  Neutrophils    CS16
# 185891   6.191045 -5.096178       19  Neutrophils    CS16
# 185892   6.637616 -5.062717       19  Neutrophils    CS16
# 185893   7.274597 -5.612700       19  Neutrophils    CS16
#
#                        cell  digest typeSample
# 0        AAACCTGAGTTCGCGC-1  exVivo    citeSeq
# 1        AAACCTGGTGAGGCTA-1  exVivo    citeSeq
# 2        AAACCTGTCGGTGTCG-1  exVivo    citeSeq
# 3        AAACGGGAGTACGCGA-1  exVivo    citeSeq
# 4        AAACGGGCAGTATGCT-1  exVivo    citeSeq
# ...                     ...     ...        ...
# 185889  TTCTTAGCACATAACC-46  exVivo   scRnaSeq
# 185890  TTGAACGAGTGAAGTT-46  exVivo   scRnaSeq
# 185891  TTGACTTTCCAATGGT-46  exVivo   scRnaSeq
# 185892  TTGTAGGTCACTCCTG-46  exVivo   scRnaSeq
# 185893  TTTCCTCTCAGCATGT-46  exVivo   scRnaSeq
#
# [185894 rows x 8 columns]

# %%
adata = adata[clusters.cell].copy()

# %%
np.testing.assert_array_equal(adata.obs_names.values, clusters.cell.values)

# %%
for c in clusters.columns:
    if "UMAP" not in c:
        adata.obs[c] = clusters[c].values.copy()

# %%
adata.obs
# Out:
#                      cluster        annot  sample                 cell  \
# AAACCTGAGTTCGCGC-1        21      T cells  CISE12   AAACCTGAGTTCGCGC-1
# AAACCTGGTGAGGCTA-1        11      T cells  CISE12   AAACCTGGTGAGGCTA-1
# AAACCTGTCGGTGTCG-1        26        ILC1s  CISE12   AAACCTGTCGGTGTCG-1
# AAACGGGAGTACGCGA-1        11      T cells  CISE12   AAACGGGAGTACGCGA-1
# AAACGGGCAGTATGCT-1        26        ILC1s  CISE12   AAACGGGCAGTATGCT-1
# ...                      ...          ...     ...                  ...
# TTCTTAGCACATAACC-46       19  Neutrophils    CS16  TTCTTAGCACATAACC-46
# TTGAACGAGTGAAGTT-46       19  Neutrophils    CS16  TTGAACGAGTGAAGTT-46
# TTGACTTTCCAATGGT-46       19  Neutrophils    CS16  TTGACTTTCCAATGGT-46
# TTGTAGGTCACTCCTG-46       19  Neutrophils    CS16  TTGTAGGTCACTCCTG-46
# TTTCCTCTCAGCATGT-46       19  Neutrophils    CS16  TTTCCTCTCAGCATGT-46
#
#                      digest typeSample
# AAACCTGAGTTCGCGC-1   exVivo    citeSeq
# AAACCTGGTGAGGCTA-1   exVivo    citeSeq
# AAACCTGTCGGTGTCG-1   exVivo    citeSeq
# AAACGGGAGTACGCGA-1   exVivo    citeSeq
# AAACGGGCAGTATGCT-1   exVivo    citeSeq
# ...                     ...        ...
# TTCTTAGCACATAACC-46  exVivo   scRnaSeq
# TTGAACGAGTGAAGTT-46  exVivo   scRnaSeq
# TTGACTTTCCAATGGT-46  exVivo   scRnaSeq
# TTGTAGGTCACTCCTG-46  exVivo   scRnaSeq
# TTTCCTCTCAGCATGT-46  exVivo   scRnaSeq
#
# [185894 rows x 6 columns]

# %%
adata.obsm["X_umap"] = clusters[["UMAP_1", "UMAP_2"]].to_numpy()

# %%
sc.pl.umap(adata, color="annot")

# %%
G = 5000
adata.layers["counts"] = adata.X.copy()
sc.pp.filter_genes(adata, min_counts=10)
sc.pp.highly_variable_genes(adata, n_top_genes=G, layer="counts", flavor="seurat_v3")
sc.pp.normalize_total(adata)
sc.pp.log1p(adata)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 185894 × 22647
#     obs: 'cluster', 'annot', 'sample', 'cell', 'digest', 'typeSample'
#     var: 'n_counts', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'sample_colors', 'annot_colors', 'hvg', 'log1p'
#     obsm: 'X_umap'
#     layers: 'counts'

# %%
path_mtx_ab = Path(
    "/Users/giovanni.palla/Datasets/moscot/rawData_mouseStSt/countTableADT_mouseStSt_overlapABs"
)
mtx_data_info = path_mtx_ab / "matrix.mtx"
with open(mtx_data_info, "r") as f:
    expr_ab = read_mtx_from_stream(f)

# %%
barcodes = pd.read_csv(path_mtx_ab / "barcodes.tsv.gz", header=None)
features = pd.read_csv(path_mtx_ab / "features.tsv.gz", header=None)

# %%
from anndata import AnnData

adata_ab = AnnData(
    expr_ab,
    obs=pd.DataFrame(index=barcodes[0].values),
    var=pd.DataFrame(index=features[0].values),
)

# %%
adata_ab
# Out:
# AnnData object with n_obs × n_vars = 181309 × 103

# %%
adata_ab = adata_ab[adata[adata.obs.typeSample == "citeSeq"].obs_names].copy()

# %%
path_save = Path("/Users/giovanni.palla/Datasets/moscot")
adata_ab.write(path_save / "adata_cite.h5ad")
adata.write(path_save / "adata_sc.h5ad")

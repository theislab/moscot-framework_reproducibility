# %%
import anndata
import scanpy as sc

# %%
import moscot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 import moscot
#
# ModuleNotFoundError: No module named 'moscot'

# %%
adata = sc.read_h5ad("/Users/dominik.klein/data/pancreas_2022_ATAC.h5ad")

# %%
dir(adata)
# Out:
# ['T',
#  'X',
#  '_BACKED_ATTRS',
#  '_H5_ALIASES',
#  '_H5_ALIASES_NAMES',
#  '_X',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_adata_ref',
#  '_check_dimensions',
#  '_check_uniqueness',
#  '_clean_up_old_format',
#  '_gen_repr',
#  '_get_X',
#  '_get_and_delete_multicol_field',
#  '_get_obs_array',
#  '_get_var_array',
#  '_has_X',
#  '_init_as_actual',
#  '_init_as_view',
#  '_inplace_subset_obs',
#  '_inplace_subset_var',
#  '_is_view',
#  '_layers',
#  '_mutated_copy',
#  '_n_obs',
#  '_n_vars',
# ...

# %%
adata.var
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
adata_red = adata[:, "19-37442282-37443209" in adata.var.index].copy()

# %%
adata_red.obs["counts"] = adata_red.X.A

# %%
import seaborn as sns

# %%
adata_red.obs
# Out:
#                                      old_index     celltype  nCount_ATAC  \
# index_adapted
# AAACAGCCAACAGCCT-1-0  E14-5_AAACAGCCAACAGCCT-1   Fev+ Alpha      25556.0
# AAACAGCCAACCCTCC-1-0  E14-5_AAACAGCCAACCCTCC-1         Fev+      43666.0
# AAACAGCCACCTGTAA-1-0  E14-5_AAACAGCCACCTGTAA-1  Imm. Acinar      35925.0
# AAACAGCCACTAAGCC-1-0  E14-5_AAACAGCCACTAAGCC-1         Fev+      35568.0
# AAACAGCCAGGATAAC-1-0  E14-5_AAACAGCCAGGATAAC-1    Ngn3 high      10507.0
# ...                                        ...          ...          ...
# TTTGTGTTCTTGTTCG-1-1  E15-5_TTTGTGTTCTTGTTCG-1       Ductal      28131.0
# TTTGTTGGTATTGAGT-1-1  E15-5_TTTGTTGGTATTGAGT-1     Ngn3 low      18048.0
# TTTGTTGGTCCTAAGA-1-1  E15-5_TTTGTTGGTCCTAAGA-1       Ductal      12931.0
# TTTGTTGGTTAACAGT-1-1  E15-5_TTTGTTGGTTAACAGT-1  Mat. Acinar      24679.0
# TTTGTTGGTTGTTGCT-1-1  E15-5_TTTGTTGGTTGTTGCT-1      Epsilon      15078.0
#
# ...

# %%
sns.barplot(data=adata_red.obs, x="celltype", y="nucleome_signal")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 sns.barplot(data=adata_red.obs, x="celltype", y="nucleome_signal")
#
# File ~/opt/anaconda3/envs/mm_best_muon_full/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
adata_red.obs.groupby("celltype").agg

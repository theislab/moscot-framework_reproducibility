# %%
devtools::install_github('quadbiolab/Pando')
# Out:
# ...
# sitmo        (2.0.1      -> 2.0.2     ) [CRAN]
# BH           (1.75.0-0   -> 1.78.0-0  ) [CRAN]
# Rcpp         (1.0.5      -> 1.0.9     ) [CRAN]
# matrixStats  (0.57.0     -> 0.63.0    ) [CRAN]
# formatR      (1.7        -> 1.12      ) [CRAN]
# DelayedArray (0.16.0     -> 0.16.3    ) [CRAN]
# MatrixGen... (1.2.0      -> 1.2.1     ) [CRAN]
# snow         (0.4-3      -> 0.4-4     ) [CRAN]
# Rhtslib      (NA         -> 1.22.0    ) [CRAN]
# bitops       (1.0-6      -> 1.0-7     ) [CRAN]
# crayon       (1.3.4      -> 1.5.2     ) [CRAN]
# GenomicAl... (NA         -> 1.26.0    ) [CRAN]
# Rsamtools    (NA         -> 2.6.0     ) [CRAN]
# RCurl        (1.98-1.2   -> 1.98-1.9  ) [CRAN]
# Biostrings   (NA         -> 2.58.0    ) [CRAN]
# GenomeInfoDb (1.26.2     -> 1.26.7    ) [CRAN]
# BiocGenerics (0.36.0     -> 0.36.1    ) [CRAN]
# XML          (3.99-0.5   -> 3.99-0.13 ) [CRAN]
# lifecycle    (0.2.0      -> 1.0.3     ) [CRAN]
# glue         (1.4.2      -> 1.6.2     ) [CRAN]
# ...
